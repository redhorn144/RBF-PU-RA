# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-1, 1)
e = 2
phi = np.exp(-e**2*(x**2))

# %%
plt.plot(x, phi)
plt.title(f'Gaussian RBF with shape parameter e={e}')
# Out:
# Text(0.5, 1.0, 'Gaussian RBF with shape parameter e=2')
